# %%
import pandas as pd

# Load the DataFrame from a CSV file (modify the file path as needed)
df = pd.read_csv("/Users/wenjing/Downloads/Capstone/10_stocks_filtered_scored.csv")

df.head()
# # Convert 'date' to datetime format for accurate filtering
# df['date'] = pd.to_datetime(df['date'])

# # Filter rows where date is 2023-12-14 and Stock_symbol is TSLA
# filtered_df = df[(df['date'] == '2023-12-14') & (df['Stock_symbol'] == 'TSLA')]

# # Display the filtered DataFrame
# print(filtered_df)
# Out:
#    Unnamed: 0                     Date  \
# 0     12025.0  2023-12-16 22:00:00 UTC
# 1     12026.0  2023-12-16 22:00:00 UTC
# 2     12027.0  2023-12-16 21:00:00 UTC
# 3     12028.0  2023-12-16 21:00:00 UTC
# 4     12029.0  2023-12-16 21:00:00 UTC
#
#                                        Article_title Stock_symbol  \
# 0  My 6 Largest Portfolio Holdings Heading Into 2...         AAPL
# 1  Brokers Suggest Investing in Apple (AAPL): Rea...         AAPL
# 2                      Company News for Dec 19, 2023         AAPL
# 3  NVIDIA (NVDA) Up 243% YTD: Will It Carry Momen...         AAPL
# 4  Pre-Market Most Active for Dec 19, 2023 : BMY,...         AAPL
#
#                                                  Url  Publisher  Author  \
# 0  https://www.nasdaq.com/articles/my-6-largest-p...        NaN     NaN
# 1  https://www.nasdaq.com/articles/brokers-sugges...        NaN     NaN
# 2  https://www.nasdaq.com/articles/company-news-f...        NaN     NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Filter rows where date is 2023-12-14 and Stock_symbol is TSLA
filtered_df = df[(df['Date'] == '2023-12-14') & (df['Stock_symbol'] == 'TSLA')]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#        Unnamed: 0                      Date  \
# 66211   2129809.0 2023-12-14 00:00:00+00:00
# 66212   2129810.0 2023-12-14 00:00:00+00:00
# 66213   2129811.0 2023-12-14 00:00:00+00:00
# 66214   2129812.0 2023-12-14 00:00:00+00:00
# 66215   2129813.0 2023-12-14 00:00:00+00:00
# 66216   2129814.0 2023-12-14 00:00:00+00:00
# 66217   2129815.0 2023-12-14 00:00:00+00:00
# 66218   2129816.0 2023-12-14 00:00:00+00:00
# 66219   2129817.0 2023-12-14 00:00:00+00:00
# 66220   2129818.0 2023-12-14 00:00:00+00:00
# 66221   2129819.0 2023-12-14 00:00:00+00:00
# 66222   2129820.0 2023-12-14 00:00:00+00:00
# 66223   2129821.0 2023-12-14 00:00:00+00:00
# 66224   2129822.0 2023-12-14 00:00:00+00:00
# 66225   2129823.0 2023-12-14 00:00:00+00:00
# 66226   2129824.0 2023-12-14 00:00:00+00:00
# 66227   2129825.0 2023-12-14 00:00:00+00:00
# 66228   2129826.0 2023-12-14 00:00:00+00:00
#
#                                            Article_title Stock_symbol  \
# ...

# %%
# Select only the specified columns in filtered_df
filtered_df = filtered_df[["sentiment_label", "sentiment_score", "Date", "Stock_symbol"]]

# Display the result
print(filtered_df)
# Out:
#       sentiment_label  sentiment_score                      Date Stock_symbol
# 66211        negative         0.920735 2023-12-14 00:00:00+00:00         TSLA
# 66212        positive         0.942635 2023-12-14 00:00:00+00:00         TSLA
# 66213         neutral         0.815022 2023-12-14 00:00:00+00:00         TSLA
# 66214        positive         0.947190 2023-12-14 00:00:00+00:00         TSLA
# 66215         neutral         0.937470 2023-12-14 00:00:00+00:00         TSLA
# 66216        positive         0.638082 2023-12-14 00:00:00+00:00         TSLA
# 66217         neutral         0.719718 2023-12-14 00:00:00+00:00         TSLA
# 66218         neutral         0.948382 2023-12-14 00:00:00+00:00         TSLA
# 66219         neutral         0.944220 2023-12-14 00:00:00+00:00         TSLA
# 66220        positive         0.906250 2023-12-14 00:00:00+00:00         TSLA
# 66221        negative         0.685471 2023-12-14 00:00:00+00:00         TSLA
# ...
